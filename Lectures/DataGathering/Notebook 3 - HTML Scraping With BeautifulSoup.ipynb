# %% [markdown]
# ## What You'll Accomplish in this Notebook
#
# Here's what you'll do in this notebook:
# <ul>
#     <li>learn about the structure of an html page</li>
#     <li>be introduced the the BeautifulSoup package</li>
#     <li>see how to parse html code with a toy example</li>
#     <li>scrape data on Seventh Son beers from some saved html code</li>
#     <li>download then scrape an actual webpage</li>
# </ul>

# %%
# Our common data handling package
import pandas as pd

# %% [markdown]
# # HTML Scraping With `BeautifulSoup`
#
# In this notebook we'll learn about how to scrape html files with <a href = "https://www.crummy.com/software/BeautifulSoup/bs4/doc/">BeautifulSoup</a>. Try running the below code.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# If that did not work take a moment to install the package.
#
# ### Understanding the Structure of an HTML Page
#
# `BeautifulSoup` takes in an html document and will 'parse' it for you so that you can extract the information you want. To best understand what that means let's look at a toy example of a webpage. To see what the snippet of html code below looks like in a web browser click here <a href="SampleHTML.html">SampleHTML.html</a>.

# %%
# This is an html chunk
# It has a head and a body, just like you
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %% [markdown]
# We can now use `BeautifulSoup` to parse this simple html chunk.

# %%
# Now we make a BeautifulSoup object our of the html code
# The first input is the html code
# The second input is how you want BeautifulSoup
# to parse the code
soup = BeautifulSoup(html_doc,'html.parser')

# %%
# Let's use the prettify method to make our html pretty and see what it has to say
# Ideally this is how someone writing pure html code would write their code
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# Html files have a natural tree structure that we'll briefly cover now. Here's the tree of our sample html:
#
# <img src = "html_tree.png" width = "500"></img>
#
# Each level in the tree represents a 'generation' of the html code. for instance the body has 3 p children, the leftmost p has one b child. `BeautifulSoup` helps us traverse these trees to gather the data we want.
#
# We'll now traverse this html sapling.

# %%
# Below are some examples of beautifulsoup methods and 
# attributes that help us better understand the structure 
# of html code

# What is the title of the page?
print(soup.title)
print()

# Notice we can also get the title like so
print(soup.head.title)
print()

# What if I just want the text from the title?
print(soup.title.text)
print()

# What html structure is the title's parent?
print(soup.title.parent.name)
print(soup.title.parent)
print()

# What is the first a of the html document?
print(soup.a)

# What is the first a's class?
print(soup.a['class'])
print()

# There are multiple a's can I find all of them?
print(soup.find_all('a'))
for a in soup.find_all('a'):
    print()
    print(a['class'], a.text)
# Out:
# <title>The Dormouse's story</title>
#
# <title>The Dormouse's story</title>
#
# The Dormouse's story
#
# head
# <head><title>The Dormouse's story</title></head>
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# ['sister']
#
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
#
# ['sister'] Elsie
#
# ['sister'] Lacie
#
# ['sister'] Tillie

# %% [markdown]
# #### Practice

# %%
# Now you practice!

# Find the first p of the document
# What is the first p's class? What string is in that p?


print(soup.p)

print(soup.p['class'])
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# ['title']

# %%
# For all of the a's in the document find their href

for a in soup.find_all('a'):
    print()
    print(a['href'])
# Out:
# http://example.com/elsie
#
# http://example.com/lacie
#
# http://example.com/tillie

# %% [markdown]
# Now we've got some experience let's move on to some slightly more advanced parsing.
#
# ### Now We're of Drinking Age
#
# I've included in this repository some html code from an <a href = "https://untappd.com/home">Untappd</a> search. We can read in that file with the following code. I went to untappd, and found the <a href = "https://www.seventhsonbrewing.com">Seventh Son</a> page then clicked on their beer list and only saved the html code from the results. You can see the html file here <a href="SeventhSon.html">SeventhSon.html</a>.

# %%
# This will save the html file's code so we can parse it
seventh_son_beer_search = open("SeventhSon.html", 'r',encoding="utf-8")

# %%
# You write code here to make a soup object of our code
# Sample Answer
soup = BeautifulSoup(seventh_son_beer_search,"html.parser", from_encoding="utf-8")

soup
# Out:
# <div class="beer-container">
# <div class="beer-item" data-bid="382779">
# <a class="label" href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-382779_814af_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-humulus-nimbus/382779">Humulus Nimbus </a></p>
# <p class="style">Pale Ale - American</p>
# <p class="desc desc-half-382779">A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart… <a class="read-more-beerlist track-click" data-bid="382779" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-382779" style="display: none;">A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart blueberry and fragrant pine to a pleasingly bitter dandelion finish. We wanted the hops to be the star in this seasonal offering taking its name from both the hop plant, Humulus Lupulus, and its light color and cloud-like feel, nimbus. <br/>
# *Pairs well with a wide range of foods from roast chicken to burgers to fish and chips, appropriate cheeses could range from a mild blue such as Gorgonzola to a traditional cheddar or Derby with Sage. <a class="read-less-beerlist track-click" data-bid="382779" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6% ABV </p><p class="ibu">
# 53 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.81)</span> </p><p class="raters">
# 10,319 Ratings </p><p class="date">
# Added 06/10/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="382779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1388263">
# <a class="label" href="/b/seventh-son-brewing-company-proliferous/1388263">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-1388263_9f172_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-proliferous/1388263">Proliferous</a></p>
# <p class="style">IPA - Imperial / Double</p>
# <p class="desc desc-half-1388263">Mosaic and a cast of supporting hops give this DIPA layers of tropical fruit and citrus with a bracing pine bitterness in the finish. </p>
# <p class="desc desc-full-1388263" style="display: none;">Mosaic and a cast of supporting hops give this DIPA layers of tropical fruit and citrus with a bracing pine bitterness in the finish. <a class="read-less-beerlist track-click" data-bid="1388263" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 8.3% ABV </p><p class="ibu">
# 85 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(4.03)</span> </p><p class="raters">
# 8,820 Ratings </p><p class="date">
# Added 01/13/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1388263" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="832910">
# <a class="label" href="/b/seventh-son-brewing-company-the-scientist/832910">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-832910_3dc2f_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-the-scientist/832910">The Scientist</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-832910">A light bodied, hop forward IPA... constantly shifting. Each batch has one ingredient changed from the last. Expect changes as we find the right balance… <a class="read-more-beerlist track-click" data-bid="832910" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-832910" style="display: none;">A light bodied, hop forward IPA... constantly shifting. Each batch has one ingredient changed from the last. Expect changes as we find the right balance of hop notes <a class="read-less-beerlist track-click" data-bid="832910" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# 75 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.82)</span> </p><p class="raters">
# 8,937 Ratings </p><p class="date">
# Added 10/04/14 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="832910" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="349430">
# <a class="label" href="/b/seventh-son-brewing-company-seventh-son-american-strong-ale/349430">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-349430_807bd_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-seventh-son-american-strong-ale/349430">Seventh Son American Strong Ale</a></p>
# <p class="style">Strong Ale - American</p>
# <p class="desc desc-half-349430">A ruddy American Strong. Grapefruit and stone fruit hop aroma and character are balanced by a rich red malt backbone. A precise blend of 7 hops go into… <a class="read-more-beerlist track-click" data-bid="349430" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-349430" style="display: none;">A ruddy American Strong. Grapefruit and stone fruit hop aroma and character are balanced by a rich red malt backbone. A precise blend of 7 hops go into the brewing and dry hopping process including Nelson Sauvin, Mosaic, Horizon, Palisade, Citra, Wilamette, and Columbus. <a class="read-less-beerlist track-click" data-bid="349430" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7.7% ABV </p><p class="ibu">
# 40 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.78)</span> </p><p class="raters">
# 7,572 Ratings </p><p class="date">
# Added 04/20/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="349430" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="358044">
# <a class="label" href="/b/seventh-son-brewing-company-stone-fort-oat-brown/358044">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-358044_fdb86_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-stone-fort-oat-brown/358044">Stone Fort Oat Brown</a></p>
# <p class="style">Brown Ale - English</p>
# <p class="desc desc-half-358044">A toasty brown ale w/accessible English ale character and a smooth blend of light roast coffee, cocoa, leather biscuit flavors. Named for the oldest structure… <a class="read-more-beerlist track-click" data-bid="358044" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-358044" style="display: none;">A toasty brown ale w/accessible English ale character and a smooth blend of light roast coffee, cocoa, leather biscuit flavors. Named for the oldest structure in Ohio. <a class="read-less-beerlist track-click" data-bid="358044" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 5.25% ABV </p><p class="ibu">
# 21 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.65)</span> </p><p class="raters">
# 5,419 Ratings </p><p class="date">
# Added 05/04/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="358044" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="438596">
# <a class="label" href="/b/seventh-son-brewing-company-oubliette/438596">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-oubliette/438596">Oubliette</a></p>
# <p class="style">Stout - American Imperial / Double</p>
# <p class="desc desc-half-438596">Oubliette (\ˌü-blē-ˈet\) is a French term for a deep, dark forgotten dungeon devoid of light and hope. Our nearly opaque Imperial Stout is black as night… <a class="read-more-beerlist track-click" data-bid="438596" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-438596" style="display: none;">Oubliette (\ˌü-blē-ˈet\) is a French term for a deep, dark forgotten dungeon devoid of light and hope. Our nearly opaque Imperial Stout is black as night with hints of plum at the edges and a rich tan head. Dark cocoa and roasted malt flavors are complimented by a lingering bitterness and a pleasingly warm alcohol glow. <a class="read-less-beerlist track-click" data-bid="438596" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 12% ABV </p><p class="ibu">
# 99 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(3.96)</span> </p><p class="raters">
# 3,432 Ratings </p><p class="date">
# Added 08/24/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="438596" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1022818">
# <a class="label" href="/b/seventh-son-brewing-company-syzygy/1022818">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-1022818_b0c19_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-syzygy/1022818">Syzygy</a></p>
# <p class="style">IPA - Imperial / Double</p>
# <p class="desc desc-half-1022818">Syzygy (\ˈsi-zə-jē\) Citra, Simcoe, Cascade hops. Rye malt and flaked Rye. Tasting notes: Sweet pine, tropical fruits, mandarin orange, intense dry bitter… <a class="read-more-beerlist track-click" data-bid="1022818" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1022818" style="display: none;">Syzygy (\ˈsi-zə-jē\) Citra, Simcoe, Cascade hops. Rye malt and flaked Rye. Tasting notes: Sweet pine, tropical fruits, mandarin orange, intense dry bitter finish. Name is a term for many things, most notibly a celestial alignment, like an eclipse. Hard to say.<br/>
# <a class="read-less-beerlist track-click" data-bid="1022818" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 10.9% ABV </p><p class="ibu">
# 100 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(4.04)</span> </p><p class="raters">
# 3,294 Ratings </p><p class="date">
# Added 03/25/15 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1022818" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="2319779">
# <a class="label" href="/b/seventh-son-brewing-company-assistant-manager/2319779">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-2319779_9a36a_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-assistant-manager/2319779">Assistant Manager</a></p>
# <p class="style">Golden Ale</p>
# <p class="desc desc-half-2319779">The definition of a drinkable and refreshing. Delicate hops and golden malts give way to firm bitterness and a clean finish. </p>
# <p class="desc desc-full-2319779" style="display: none;">The definition of a drinkable and refreshing. Delicate hops and golden malts give way to firm bitterness and a clean finish. <a class="read-less-beerlist track-click" data-bid="2319779" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 4.5% ABV </p><p class="ibu">
# 36 IBU </p><p class="rating">
# <span class="rating small r350"></span>
# <span class="num">(3.57)</span> </p><p class="raters">
# 2,470 Ratings </p><p class="date">
# Added 10/01/17 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="2319779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1515633">
# <a class="label" href="/b/seventh-son-brewing-company-goo-goo-muck-tart-ipa/1515633">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-1515633_2254c_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-goo-goo-muck-tart-ipa/1515633">Goo Goo Muck</a></p>
# <p class="style">Sour - Farmhouse IPA</p>
# <p class="desc desc-half-1515633">We dry hopped this kettle-soured IPA with Citra, Simcoe and Palisade for a juicy mango-grapefruit flavor and aroma. Sourness takes the place of bitterness… <a class="read-more-beerlist track-click" data-bid="1515633" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1515633" style="display: none;">We dry hopped this kettle-soured IPA with Citra, Simcoe and Palisade for a juicy mango-grapefruit flavor and aroma. Sourness takes the place of bitterness in balancing out the sweetness of the malts. <a class="read-less-beerlist track-click" data-bid="1515633" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7.6% ABV </p><p class="ibu">
# 50 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.81)</span> </p><p class="raters">
# 2,359 Ratings </p><p class="date">
# Added 04/17/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1515633" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="462190">
# <a class="label" href="/b/seventh-son-brewing-company-golden-ratio/462190">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-golden-ratio/462190">Golden Ratio</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-462190">Brewed with local honey. Galaxy, Nelson Sauvin, Moteuka hops. Tasting notes: toasty malts, tropical fruit hops. </p>
# <p class="desc desc-full-462190" style="display: none;">Brewed with local honey. Galaxy, Nelson Sauvin, Moteuka hops. Tasting notes: toasty malts, tropical fruit hops. <a class="read-less-beerlist track-click" data-bid="462190" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# 68 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.75)</span> </p><p class="raters">
# 1,780 Ratings </p><p class="date">
# Added 09/26/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="462190" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="2201055">
# <a class="label" href="/b/seventh-son-brewing-company-gleen/2201055">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-gleen/2201055">Gleen</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-2201055">Northeast IPA methods and four dry hop additions meet Midwest sensibilities for a burst of pungent hoppy sunshine in this “no coast” IPA from the banks… <a class="read-more-beerlist track-click" data-bid="2201055" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-2201055" style="display: none;">Northeast IPA methods and four dry hop additions meet Midwest sensibilities for a burst of pungent hoppy sunshine in this “no coast” IPA from the banks of the Olentangy. <a class="read-less-beerlist track-click" data-bid="2201055" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7.9% ABV </p><p class="ibu">
# 55 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(3.91)</span> </p><p class="raters">
# 1,632 Ratings </p><p class="date">
# Added 07/19/17 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="2201055" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="380322">
# <a class="label" href="/b/seventh-son-brewing-company-lost-sparrow/380322">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-lost-sparrow/380322">Lost Sparrow</a></p>
# <p class="style">IPA - Black / Cascadian Dark Ale</p>
# <p class="desc desc-half-380322">Midnight dark, bracingly bitter yet smooth black IPA with dark malt character balanced by notes of lemon and orange rind from extensive dry hopping with… <a class="read-more-beerlist track-click" data-bid="380322" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-380322" style="display: none;">Midnight dark, bracingly bitter yet smooth black IPA with dark malt character balanced by notes of lemon and orange rind from extensive dry hopping with Sorachi Ace. <a class="read-less-beerlist track-click" data-bid="380322" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6.7% ABV </p><p class="ibu">
# 75 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.66)</span> </p><p class="raters">
# 1,519 Ratings </p><p class="date">
# Added 06/07/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="380322" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1868972">
# <a class="label" href="/b/seventh-son-brewing-company-fox-in-the-stout/1868972">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-fox-in-the-stout/1868972">Fox In the Stout</a></p>
# <p class="style">Stout - American Imperial / Double</p>
# <p class="desc desc-half-1868972">Fox in the Stout Imperial Salted Chocolate Stout: cocoa nibs and fresh vanilla beans along with flaked oats for body make this a big rich dessert stout… <a class="read-more-beerlist track-click" data-bid="1868972" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1868972" style="display: none;">Fox in the Stout Imperial Salted Chocolate Stout: cocoa nibs and fresh vanilla beans along with flaked oats for body make this a big rich dessert stout worthy of its Fox in the Snow brownie inspiration. <a class="read-less-beerlist track-click" data-bid="1868972" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 9.7% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r425"></span>
# <span class="num">(4.22)</span> </p><p class="raters">
# 1,501 Ratings </p><p class="date">
# Added 12/18/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1868972" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="471148">
# <a class="label" href="/b/seventh-son-brewing-company-wilderman/471148">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-471148_140c5_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-wilderman/471148">Wilderman</a></p>
# <p class="style">Bière de Garde</p>
# <p class="desc desc-half-471148">Inspired by the European pagan Fall tradition of Wilder Mann costumes, our Wildermann is a biere de garde with a bit more hop than French versions and… <a class="read-more-beerlist track-click" data-bid="471148" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-471148" style="display: none;">Inspired by the European pagan Fall tradition of Wilder Mann costumes, our Wildermann is a biere de garde with a bit more hop than French versions and clean farmhouse yeast spice. We lagered for a month which mellows the character of the beer and lets the malt shine. <a class="read-less-beerlist track-click" data-bid="471148" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7.6% ABV </p><p class="ibu">
# 22 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.68)</span> </p><p class="raters">
# 1,443 Ratings </p><p class="date">
# Added 10/06/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="471148" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="581623">
# <a class="label" href="/b/seventh-son-brewing-company-mr-owl/581623">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-581623_72b32_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-mr-owl/581623">Mr. Owl</a></p>
# <p class="style">Brown Ale - Imperial / Double</p>
# <p class="desc desc-half-581623">Citra, northern brewer, horizon hops. Housemade Candi Syrup. Tasting notes:rich milk chocolate, tropical fruit, orange zest. bottle release fall, named… <a class="read-more-beerlist track-click" data-bid="581623" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-581623" style="display: none;">Citra, northern brewer, horizon hops. Housemade Candi Syrup. Tasting notes:rich milk chocolate, tropical fruit, orange zest.<br/>
# bottle release fall, named after the tootsie roll commercial. Have fun and enjoy Mr. Owl with anything from candy-coated lollipops too spicy mole sauce, or even a foie gras torchon. <a class="read-less-beerlist track-click" data-bid="581623" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 8.5% ABV </p><p class="ibu">
# 73 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.79)</span> </p><p class="raters">
# 1,445 Ratings </p><p class="date">
# Added 02/07/14 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="581623" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="534959">
# <a class="label" href="/b/seventh-son-brewing-company-ladies-and-gentlemen/534959">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-ladies-and-gentlemen/534959">Ladies And Gentlemen</a></p>
# <p class="style">Barleywine - American</p>
# <p class="desc desc-half-534959">Fine carbonation carries Aromas of peach cake, clementines and flowers, balanced by a firm, Happy bitterness and hints of vanilla icing in the finish.… <a class="read-more-beerlist track-click" data-bid="534959" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-534959" style="display: none;">Fine carbonation carries Aromas of peach cake, clementines and flowers, balanced by a firm, Happy bitterness and hints of vanilla icing in the finish. <a class="read-less-beerlist track-click" data-bid="534959" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 11% ABV </p><p class="ibu">
# 51 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.82)</span> </p><p class="raters">
# 1,358 Ratings </p><p class="date">
# Added 12/18/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="534959" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1390772">
# <a class="label" href="/b/seventh-son-brewing-company-brother-jon/1390772">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-brother-jon/1390772">Brother Jon</a></p>
# <p class="style">Blonde Ale - Belgian Blonde / Golden</p>
# <p class="desc desc-half-1390772">Heull Melon, Palisade Hops. A blend of two Belgian abbey style yeasts. Tasting Notes: Faint fruit and spice, crackery malt. Mild beer traditionaly brewed… <a class="read-more-beerlist track-click" data-bid="1390772" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1390772" style="display: none;">Heull Melon, Palisade Hops.<br/>
# A blend of two Belgian abbey style yeasts. Tasting Notes:<br/>
# Faint fruit and spice, crackery malt. Mild beer traditionaly brewed by Belgian monks, named after a local celeb and wedding officant Jon Putnam. <a class="read-less-beerlist track-click" data-bid="1390772" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6.3% ABV </p><p class="ibu">
# 30 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.63)</span> </p><p class="raters">
# 1,347 Ratings </p><p class="date">
# Added 01/16/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1390772" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1057580">
# <a class="label" href="/b/seventh-son-brewing-company-chester-copperpot/1057580">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-1057580_bb6dd_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-chester-copperpot/1057580">Chester Copperpot</a></p>
# <p class="style">Smoked Beer</p>
# <p class="desc desc-half-1057580">Old-school German-style Hallertauer Hersbrucker, Willamette hops. Beech and Cherrywood smoked malts. Tasting notes: Sweet smokiness, clean bodied, herbal… <a class="read-more-beerlist track-click" data-bid="1057580" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1057580" style="display: none;">Old-school German-style Hallertauer Hersbrucker, Willamette hops. Beech and Cherrywood smoked malts. Tasting notes: Sweet smokiness, clean bodied, herbal lingering bitterness. Goonies never say die!! <a class="read-less-beerlist track-click" data-bid="1057580" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7.9% ABV </p><p class="ibu">
# 6 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.7)</span> </p><p class="raters">
# 1,323 Ratings </p><p class="date">
# Added 04/23/15 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1057580" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="557738">
# <a class="label" href="/b/seventh-son-brewing-company-willowolf/557738">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-willowolf/557738">Willowolf</a></p>
# <p class="style">IPA - Imperial / Double</p>
# <p class="desc desc-half-557738">Amarillo, Centennial, Horizon hops. Tasting notes:bitter pine and citrus, sweet finish. named for an archaic term for the hops plant, because the vines… <a class="read-more-beerlist track-click" data-bid="557738" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-557738" style="display: none;">Amarillo, Centennial, Horizon hops. Tasting notes:bitter pine and citrus, sweet finish. named for an archaic term for the hops plant, because the vines can choke willow trees <a class="read-less-beerlist track-click" data-bid="557738" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 9.3% ABV </p><p class="ibu">
# 120 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(3.92)</span> </p><p class="raters">
# 1,159 Ratings </p><p class="date">
# Added 01/11/14 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="557738" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1309047">
# <a class="label" href="/b/seventh-son-brewing-company-rime/1309047">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-rime/1309047">Rime</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-1309047">Lightly spiced Winter IPA uses fresh ginger, coriander, and caramelized orange peels </p>
# <p class="desc desc-full-1309047" style="display: none;">Lightly spiced Winter IPA uses fresh ginger, coriander, and caramelized orange peels <a class="read-less-beerlist track-click" data-bid="1309047" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6.5% ABV </p><p class="ibu">
# 53 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.78)</span> </p><p class="raters">
# 1,166 Ratings </p><p class="date">
# Added 11/11/15 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1309047" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="496043">
# <a class="label" href="/b/seventh-son-brewing-company-black-sheep/496043">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-black-sheep/496043">Black Sheep</a></p>
# <p class="style">Stout - Other</p>
# <p class="desc desc-half-496043">This dry-hopped American stout has a full body with notes of fresh roasted coffee, cocoa and cherrywood smoke. </p>
# <p class="desc desc-full-496043" style="display: none;">This dry-hopped American stout has a full body with notes of fresh roasted coffee, cocoa and cherrywood smoke. <a class="read-less-beerlist track-click" data-bid="496043" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# 30 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.64)</span> </p><p class="raters">
# 1,096 Ratings </p><p class="date">
# Added 11/04/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="496043" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1534210">
# <a class="label" href="/b/seventh-son-brewing-company-hadron-s-collision-table-beer/1534210">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-hadron-s-collision-table-beer/1534210">Hadron's Collision Table Beer</a></p>
# <p class="style">Saison / Farmhouse Ale</p>
# <p class="desc desc-half-1534210">Light cantaloupe aroma and flavors arrive courtesy of the singular Huell Melon hops </p>
# <p class="desc desc-full-1534210" style="display: none;">Light cantaloupe aroma and flavors arrive courtesy of the singular Huell Melon hops <a class="read-less-beerlist track-click" data-bid="1534210" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 3.4% ABV </p><p class="ibu">
# 20 IBU </p><p class="rating">
# <span class="rating small r325"></span>
# <span class="num">(3.32)</span> </p><p class="raters">
# 1,074 Ratings </p><p class="date">
# Added 04/30/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1534210" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1286407">
# <a class="label" href="/b/seventh-son-brewing-company-laniakea/1286407">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-laniakea/1286407">Laniakea</a></p>
# <p class="style">IPA - Imperial / Double</p>
# <p class="desc desc-half-1286407">Laniakea (La-ni-akea)Loads of Galaxy and Mosaic hops dominate this hugely aromatic double named for the cosmic super cluster that is home to our own Milky… <a class="read-more-beerlist track-click" data-bid="1286407" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1286407" style="display: none;">Laniakea (La-ni-akea)Loads of Galaxy and Mosaic hops dominate this hugely aromatic double named for the cosmic super cluster that is home to our own Milky Way. <a class="read-less-beerlist track-click" data-bid="1286407" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 9.5% ABV </p><p class="ibu">
# 100 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(3.98)</span> </p><p class="raters">
# 1,021 Ratings </p><p class="date">
# Added 10/24/15 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1286407" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1256707">
# <a class="label" href="/b/seventh-son-brewing-company-sun-mouth/1256707">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-sun-mouth/1256707">Sun Mouth</a></p>
# <p class="style">Saison / Farmhouse Ale</p>
# <p class="desc desc-half-1256707">This off-dry strong saison has a melange of fruit and spice flavors. Sorachi Ace and Citra hops bring dill and candied lemon while our blend of farmhouse… <a class="read-more-beerlist track-click" data-bid="1256707" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1256707" style="display: none;">This off-dry strong saison has a melange of fruit and spice flavors. Sorachi Ace and Citra hops bring dill and candied lemon while our blend of farmhouse yeast layer in white pepper spice. Pilsner and wheat malts lend a bready finish. Put the sun in your mouth <a class="read-less-beerlist track-click" data-bid="1256707" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 8.3% ABV </p><p class="ibu">
# 30 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.66)</span> </p><p class="raters">
# 986 Ratings </p><p class="date">
# Added 10/01/15 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1256707" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1441216">
# <a class="label" href="/b/seventh-son-brewing-company-abaddon/1441216">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-abaddon/1441216">Abaddon</a></p>
# <p class="style">Belgian Quad</p>
# <p class="desc desc-half-1441216">Mosaic, Saaz hops. Dark housemade candi syrups, abbey yeast blend, spices. Tasting notes: Dried fruit, bitter orange, white pepper, port wine sweetness.… <a class="read-more-beerlist track-click" data-bid="1441216" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1441216" style="display: none;">Mosaic, Saaz hops. <br/>
# Dark housemade candi syrups, abbey yeast blend, spices.<br/>
# Tasting notes:<br/>
# Dried fruit, bitter orange, white pepper, port wine sweetness. <br/>
# Named after a destroying angel <a class="read-less-beerlist track-click" data-bid="1441216" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 10% ABV </p><p class="ibu">
# 30 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.86)</span> </p><p class="raters">
# 971 Ratings </p><p class="date">
# Added 02/25/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="1441216" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>
# <div class="beer-item" data-bid="1249048">
# <a class="label" href="/b/seventh-son-brewing-company-the-wild-hunt/1249048">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-the-wild-hunt/1249048">The Wild Hunt</a></p>
# <p class="style">Barleywine - English</p>
# <p class="desc desc-half-1249048">Inspired by the myths, legends and magic of the English countryside, this barleywine marks the transition from the exuberance of Summer to the hush of… <a class="read-more-beerlist track-click" data-bid="1249048" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1249048" style="display: none;">Inspired by the myths, legends and magic of the English countryside, this barleywine marks the transition from the exuberance of Summer to the hush of Autumn. Premium English malts lend a rich body, juicy cherry notes and a deep caramel complexity. Assertively hopped when fresh, this layered ale will continue to evolve in the bottle for many years. <a class="read-less-beerlist track-click" data-bid="1249048" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 9.8% ABV </p><p class="ibu">
# 55 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.78)</span> </p><p class="raters">
# 954 Ratings </p><p class="date">
# Added 09/25/15 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="1249048" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="2125648">
# <a class="label" href="/b/seventh-son-brewing-company-qahwah-arab-imperial-coffee-stout/2125648">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-qahwah-arab-imperial-coffee-stout/2125648">Qahwah Arab Imperial Coffee Stout</a></p>
# <p class="style">Stout - American</p>
# <p class="desc desc-half-2125648">Arab Coffee Stout. A medium bodied Imperial Stout infused with Mission Coffee beans, cardamom, clove, cinnamon and ginger. </p>
# <p class="desc desc-full-2125648" style="display: none;">Arab Coffee Stout. A medium bodied Imperial Stout infused with Mission Coffee beans, cardamom, clove, cinnamon and ginger. <a class="read-less-beerlist track-click" data-bid="2125648" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 9% ABV </p><p class="ibu">
# 40 IBU </p><p class="rating">
# <span class="rating small r400"></span>
# <span class="num">(4.12)</span> </p><p class="raters">
# 861 Ratings </p><p class="date">
# Added 06/03/17 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="2125648" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="2335634">
# <a class="label" href="/b/seventh-son-brewing-company-lemongrass-wit-sketch/2335634">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-lemongrass-wit-sketch/2335634">Lemongrass Wit</a></p>
# <p class="style">Witbier</p>
# <p class="desc desc-half-2335634">A new-world spin on the classic Belgian Wit. Lemongrass, lime leaves and Lemondrop hops combine with fresh ground coriander to give this quenching wheat… <a class="read-more-beerlist track-click" data-bid="2335634" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-2335634" style="display: none;">A new-world spin on the classic Belgian Wit. Lemongrass, lime leaves and Lemondrop hops combine with fresh ground coriander to give this quenching wheat ale a citrusy zip. <a class="read-less-beerlist track-click" data-bid="2335634" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 4.9% ABV </p><p class="ibu">
# 10 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.65)</span> </p><p class="raters">
# 867 Ratings </p><p class="date">
# Added 10/12/17 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="2335634" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="1431911">
# <a class="label" href="/b/seventh-son-brewing-company-baphomet/1431911">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-baphomet/1431911">Baphomet</a></p>
# <p class="style">Belgian Tripel</p>
# <p class="desc desc-half-1431911">Galaxy, Saaz hops: blonde housemade candi syrup, abbey yeast blend. Tasting notes: Complex fruit and spice nose, a zesty middle, finishes bitter and crisp.… <a class="read-more-beerlist track-click" data-bid="1431911" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-1431911" style="display: none;">Galaxy, Saaz hops: blonde housemade candi syrup, abbey yeast blend. Tasting notes:<br/>
# Complex fruit and spice nose, a zesty middle, finishes bitter and crisp. Traditionally named after the devil due to it's strength. Symbol of the modern satanic church. <br/>
# <a class="read-less-beerlist track-click" data-bid="1431911" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 10.2% ABV </p><p class="ibu">
# 35 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.78)</span> </p><p class="raters">
# 782 Ratings </p><p class="date">
# Added 02/17/16 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="1431911" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="2840898">
# <a class="label" href="/b/seventh-son-brewing-company-tessera/2840898">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-tessera/2840898">Tessera</a></p>
# <p class="style">IPA - New England</p>
# <p class="desc desc-half-2840898">Golden-yellow hazy, hopped with Mosaic at a monsterous 7 pounds per barrel. Cannabis, mango and ripe pineapple leads into a dry quenching finish. </p>
# <p class="desc desc-full-2840898" style="display: none;">Golden-yellow hazy, hopped with Mosaic at a monsterous 7 pounds per barrel. Cannabis, mango and ripe pineapple leads into a dry quenching finish. <a class="read-less-beerlist track-click" data-bid="2840898" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6.4% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.82)</span> </p><p class="raters">
# 743 Ratings </p><p class="date">
# Added 09/11/18 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="2840898" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="389988">
# <a class="label" href="/b/seventh-son-brewing-company-prime-swarm/389988">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-389988_42273_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-prime-swarm/389988">Prime Swarm</a></p>
# <p class="style">Saison / Farmhouse Ale</p>
# <p class="desc desc-half-389988">Crystal, Citra hops. Local raw honey. Tasting notes: dry finish, sweet honey aroma, yeast spice. bottle release in the summer, very dry, honey-forward… <a class="read-more-beerlist track-click" data-bid="389988" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-389988" style="display: none;">Crystal, Citra hops. Local raw honey. Tasting notes: dry finish, sweet honey aroma, yeast spice. bottle release in the summer, very dry, honey-forward saison <a class="read-less-beerlist track-click" data-bid="389988" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# 27 IBU </p><p class="rating">
# <span class="rating small r350"></span>
# <span class="num">(3.58)</span> </p><p class="raters">
# 639 Ratings </p><p class="date">
# Added 06/22/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="389988" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="1230953">
# <a class="label" href="/b/seventh-son-brewing-company-bibendum/1230953">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-bibendum/1230953">Bibendum</a></p>
# <p class="style">Stout - American</p>
# <p class="desc desc-half-1230953">Inspired by our building's past as a car garage, this bulbous stout adopts the name of a famous tire icon. The mellow roast of the malt combines with… <a class="read-more-beerlist track-click" data-bid="1230953" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# ...
# 6 Ratings </p><p class="date">
# Added 02/14/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3081502" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3123735">
# <a class="label" href="/b/seventh-son-brewing-company-sunmouth-with-toasted-coconut-and-pineapple/3123735">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-sunmouth-with-toasted-coconut-and-pineapple/3123735">Sunmouth (with Toasted Coconut And Pineapple)</a></p>
# <p class="style">Saison / Farmhouse Ale</p>
# <p class="desc desc-half-3123735"> </p>
# <p class="desc desc-full-3123735" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3123735" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 8.3% ABV </p><p class="ibu">
# 30 IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 7 Ratings </p><p class="date">
# Added 03/13/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3123735" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3059258">
# <a class="label" href="/b/seventh-son-brewing-company-seveth-son-scientist-5ai/3059258">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-seveth-son-scientist-5ai/3059258">Seveth Son Scientist #5AI</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-3059258">American IPA </p>
# <p class="desc desc-full-3059258" style="display: none;">American IPA <a class="read-less-beerlist track-click" data-bid="3059258" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# 75 IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 5 Ratings </p><p class="date">
# Added 01/30/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3059258" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3195710">
# <a class="label" href="/b/seventh-son-brewing-company-sike/3195710">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-sike/3195710">Sike</a></p>
# <p class="style">Sour - Fruited</p>
# <p class="desc desc-half-3195710"> </p>
# <p class="desc desc-full-3195710" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3195710" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# N/A ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 6 Ratings </p><p class="date">
# Added 04/25/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3195710" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3072514">
# <a class="label" href="/b/seventh-son-brewing-company-seventh-son-saddle-lamp/3072514">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-seventh-son-saddle-lamp/3072514">Seventh Son Saddle Lamp</a></p>
# <p class="style">Sour - Ale</p>
# <p class="desc desc-half-3072514"> </p>
# <p class="desc desc-full-3072514" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3072514" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6.8% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 5 Ratings </p><p class="date">
# Added 02/08/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3072514" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3142240">
# <a class="label" href="/b/seventh-son-brewing-company-seventh-son-stone-fort-coffee-and-vanilla-cask/3142240">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-seventh-son-stone-fort-coffee-and-vanilla-cask/3142240">Seventh Son Stone Fort Coffee And Vanilla Cask</a></p>
# <p class="style">Brown Ale - American</p>
# <p class="desc desc-half-3142240"> </p>
# <p class="desc desc-full-3142240" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3142240" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 5.3% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 5 Ratings </p><p class="date">
# Added 03/23/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3142240" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3187805">
# <a class="label" href="/b/seventh-son-brewing-company-proliferous-2019/3187805">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-proliferous-2019/3187805">Proliferous 2019</a></p>
# <p class="style">IPA - Imperial / Double</p>
# <p class="desc desc-half-3187805"> </p>
# <p class="desc desc-full-3187805" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3187805" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 8.3% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 4 Ratings </p><p class="date">
# Added 04/20/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3187805" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3066342">
# <a class="label" href="/b/seventh-son-brewing-company-scientist-5aj/3066342">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-scientist-5aj/3066342">Scientist 5AJ</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-3066342"> </p>
# <p class="desc desc-full-3066342" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3066342" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 4 Ratings </p><p class="date">
# Added 02/03/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3066342" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3143625">
# <a class="label" href="/b/seventh-son-brewing-company-barrel-aged-oubliette-2019/3143625">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-barrel-aged-oubliette-2019/3143625">Barrel Aged Oubliette 2019</a></p>
# <p class="style">Stout - American Imperial / Double</p>
# <p class="desc desc-half-3143625">Blended from ages of Oubliette that spent time in two rum barrels, two bourbon barrels and an apple brandy barrel </p>
# <p class="desc desc-full-3143625" style="display: none;">Blended from ages of Oubliette that spent time in two rum barrels, two bourbon barrels and an apple brandy barrel <a class="read-less-beerlist track-click" data-bid="3143625" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 13% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 4 Ratings </p><p class="date">
# Added 03/24/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3143625" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3182114">
# <a class="label" href="/b/seventh-son-brewing-company-low-hanging-fruit/3182114">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-low-hanging-fruit/3182114">Low Hanging Fruit</a></p>
# <p class="style">Sour - Farmhouse IPA</p>
# <p class="desc desc-half-3182114"> </p>
# <p class="desc desc-full-3182114" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3182114" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7.2% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 4 Ratings </p><p class="date">
# Added 04/17/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3182114" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3148710">
# <a class="label" href="/b/seventh-son-brewing-company-the-scientist-4al/3148710">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-the-scientist-4al/3148710">The Scientist #4AL</a></p>
# <p class="style">IPA - American</p>
# <p class="desc desc-half-3148710"> </p>
# <p class="desc desc-full-3148710" style="display: none;"> <a class="read-less-beerlist track-click" data-bid="3148710" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 7% ABV </p><p class="ibu">
# 70 IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 1 Rating </p><p class="date">
# Added 03/28/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3148710" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# <div class="beer-item" data-bid="3200294">
# <a class="label" href="/b/seventh-son-brewing-company-dang-w-pineapple-mango-and-habanero/3200294">
# <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-dang-w-pineapple-mango-and-habanero/3200294">Dang! W/ Pineapple, Mango And Habanero</a></p>
# <p class="style">IPA - Imperial / Double</p>
# <p class="desc desc-half-3200294">Infused </p>
# <p class="desc desc-full-3200294" style="display: none;">Infused <a class="read-less-beerlist track-click" data-bid="3200294" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 9.7% ABV </p><p class="ibu">
# N/A IBU </p><p class="rating">
# <span class="rating small r000"></span>
# <span class="num">(<a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">N/A</a>)</span> </p><p class="raters">
# 1 Rating </p><p class="date">
# Added 04/27/19 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3200294" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a>
# </div>
# </div>

# %%
# Look at the code using prettify
# Sample Answer
print(soup.prettify())
# Out:
# <div class="beer-container">
#  <div class="beer-item" data-bid="382779">
#   <a class="label" href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-382779_814af_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
#      Humulus Nimbus
#     </a>
#    </p>
#    <p class="style">
#     Pale Ale - American
#    </p>
#    <p class="desc desc-half-382779">
#     A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart…
#     <a class="read-more-beerlist track-click" data-bid="382779" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-382779" style="display: none;">
#     A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart blueberry and fragrant pine to a pleasingly bitter dandelion finish. We wanted the hops to be the star in this seasonal offering taking its name from both the hop plant, Humulus Lupulus, and its light color and cloud-like feel, nimbus.
#     <br/>
#     *Pairs well with a wide range of foods from roast chicken to burgers to fish and chips, appropriate cheeses could range from a mild blue such as Gorgonzola to a traditional cheddar or Derby with Sage.
#     <a class="read-less-beerlist track-click" data-bid="382779" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     6% ABV
#    </p>
#    <p class="ibu">
#     53 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.81)
#     </span>
#    </p>
#    <p class="raters">
#     10,319 Ratings
#    </p>
#    <p class="date">
#     Added 06/10/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="382779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1388263">
#   <a class="label" href="/b/seventh-son-brewing-company-proliferous/1388263">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-1388263_9f172_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-proliferous/1388263">
#      Proliferous
#     </a>
#    </p>
#    <p class="style">
#     IPA - Imperial / Double
#    </p>
#    <p class="desc desc-half-1388263">
#     Mosaic and a cast of supporting hops give this DIPA layers of tropical fruit and citrus with a bracing pine bitterness in the finish.
#    </p>
#    <p class="desc desc-full-1388263" style="display: none;">
#     Mosaic and a cast of supporting hops give this DIPA layers of tropical fruit and citrus with a bracing pine bitterness in the finish.
#     <a class="read-less-beerlist track-click" data-bid="1388263" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     8.3% ABV
#    </p>
#    <p class="ibu">
#     85 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (4.03)
#     </span>
#    </p>
#    <p class="raters">
#     8,820 Ratings
#    </p>
#    <p class="date">
#     Added 01/13/16
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1388263" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="832910">
#   <a class="label" href="/b/seventh-son-brewing-company-the-scientist/832910">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-832910_3dc2f_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-the-scientist/832910">
#      The Scientist
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-832910">
#     A light bodied, hop forward IPA... constantly shifting. Each batch has one ingredient changed from the last. Expect changes as we find the right balance…
#     <a class="read-more-beerlist track-click" data-bid="832910" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-832910" style="display: none;">
#     A light bodied, hop forward IPA... constantly shifting. Each batch has one ingredient changed from the last. Expect changes as we find the right balance of hop notes
#     <a class="read-less-beerlist track-click" data-bid="832910" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7% ABV
#    </p>
#    <p class="ibu">
#     75 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.82)
#     </span>
#    </p>
#    <p class="raters">
#     8,937 Ratings
#    </p>
#    <p class="date">
#     Added 10/04/14
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="832910" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="349430">
#   <a class="label" href="/b/seventh-son-brewing-company-seventh-son-american-strong-ale/349430">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-349430_807bd_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-seventh-son-american-strong-ale/349430">
#      Seventh Son American Strong Ale
#     </a>
#    </p>
#    <p class="style">
#     Strong Ale - American
#    </p>
#    <p class="desc desc-half-349430">
#     A ruddy American Strong. Grapefruit and stone fruit hop aroma and character are balanced by a rich red malt backbone. A precise blend of 7 hops go into…
#     <a class="read-more-beerlist track-click" data-bid="349430" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-349430" style="display: none;">
#     A ruddy American Strong. Grapefruit and stone fruit hop aroma and character are balanced by a rich red malt backbone. A precise blend of 7 hops go into the brewing and dry hopping process including Nelson Sauvin, Mosaic, Horizon, Palisade, Citra, Wilamette, and Columbus.
#     <a class="read-less-beerlist track-click" data-bid="349430" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7.7% ABV
#    </p>
#    <p class="ibu">
#     40 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.78)
#     </span>
#    </p>
#    <p class="raters">
#     7,572 Ratings
#    </p>
#    <p class="date">
#     Added 04/20/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="349430" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="358044">
#   <a class="label" href="/b/seventh-son-brewing-company-stone-fort-oat-brown/358044">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-358044_fdb86_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-stone-fort-oat-brown/358044">
#      Stone Fort Oat Brown
#     </a>
#    </p>
#    <p class="style">
#     Brown Ale - English
#    </p>
#    <p class="desc desc-half-358044">
#     A toasty brown ale w/accessible English ale character and a smooth blend of light roast coffee, cocoa, leather biscuit flavors. Named for the oldest structure…
#     <a class="read-more-beerlist track-click" data-bid="358044" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-358044" style="display: none;">
#     A toasty brown ale w/accessible English ale character and a smooth blend of light roast coffee, cocoa, leather biscuit flavors. Named for the oldest structure in Ohio.
#     <a class="read-less-beerlist track-click" data-bid="358044" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     5.25% ABV
#    </p>
#    <p class="ibu">
#     21 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.65)
#     </span>
#    </p>
#    <p class="raters">
#     5,419 Ratings
#    </p>
#    <p class="date">
#     Added 05/04/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="358044" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="438596">
#   <a class="label" href="/b/seventh-son-brewing-company-oubliette/438596">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-oubliette/438596">
#      Oubliette
#     </a>
#    </p>
#    <p class="style">
#     Stout - American Imperial / Double
#    </p>
#    <p class="desc desc-half-438596">
#     Oubliette (\ˌü-blē-ˈet\) is a French term for a deep, dark forgotten dungeon devoid of light and hope. Our nearly opaque Imperial Stout is black as night…
#     <a class="read-more-beerlist track-click" data-bid="438596" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-438596" style="display: none;">
#     Oubliette (\ˌü-blē-ˈet\) is a French term for a deep, dark forgotten dungeon devoid of light and hope. Our nearly opaque Imperial Stout is black as night with hints of plum at the edges and a rich tan head. Dark cocoa and roasted malt flavors are complimented by a lingering bitterness and a pleasingly warm alcohol glow.
#     <a class="read-less-beerlist track-click" data-bid="438596" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     12% ABV
#    </p>
#    <p class="ibu">
#     99 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (3.96)
#     </span>
#    </p>
#    <p class="raters">
#     3,432 Ratings
#    </p>
#    <p class="date">
#     Added 08/24/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="438596" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1022818">
#   <a class="label" href="/b/seventh-son-brewing-company-syzygy/1022818">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-1022818_b0c19_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-syzygy/1022818">
#      Syzygy
#     </a>
#    </p>
#    <p class="style">
#     IPA - Imperial / Double
#    </p>
#    <p class="desc desc-half-1022818">
#     Syzygy (\ˈsi-zə-jē\) Citra, Simcoe, Cascade hops. Rye malt and flaked Rye. Tasting notes: Sweet pine, tropical fruits, mandarin orange, intense dry bitter…
#     <a class="read-more-beerlist track-click" data-bid="1022818" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1022818" style="display: none;">
#     Syzygy (\ˈsi-zə-jē\) Citra, Simcoe, Cascade hops. Rye malt and flaked Rye. Tasting notes: Sweet pine, tropical fruits, mandarin orange, intense dry bitter finish. Name is a term for many things, most notibly a celestial alignment, like an eclipse. Hard to say.
#     <br/>
#     <a class="read-less-beerlist track-click" data-bid="1022818" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     10.9% ABV
#    </p>
#    <p class="ibu">
#     100 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (4.04)
#     </span>
#    </p>
#    <p class="raters">
#     3,294 Ratings
#    </p>
#    <p class="date">
#     Added 03/25/15
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1022818" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="2319779">
#   <a class="label" href="/b/seventh-son-brewing-company-assistant-manager/2319779">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-2319779_9a36a_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-assistant-manager/2319779">
#      Assistant Manager
#     </a>
#    </p>
#    <p class="style">
#     Golden Ale
#    </p>
#    <p class="desc desc-half-2319779">
#     The definition of a drinkable and refreshing. Delicate hops and golden malts give way to firm bitterness and a clean finish.
#    </p>
#    <p class="desc desc-full-2319779" style="display: none;">
#     The definition of a drinkable and refreshing. Delicate hops and golden malts give way to firm bitterness and a clean finish.
#     <a class="read-less-beerlist track-click" data-bid="2319779" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     4.5% ABV
#    </p>
#    <p class="ibu">
#     36 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r350">
#     </span>
#     <span class="num">
#      (3.57)
#     </span>
#    </p>
#    <p class="raters">
#     2,470 Ratings
#    </p>
#    <p class="date">
#     Added 10/01/17
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="2319779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1515633">
#   <a class="label" href="/b/seventh-son-brewing-company-goo-goo-muck-tart-ipa/1515633">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-1515633_2254c_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-goo-goo-muck-tart-ipa/1515633">
#      Goo Goo Muck
#     </a>
#    </p>
#    <p class="style">
#     Sour - Farmhouse IPA
#    </p>
#    <p class="desc desc-half-1515633">
#     We dry hopped this kettle-soured IPA with Citra, Simcoe and Palisade for a juicy mango-grapefruit flavor and aroma. Sourness takes the place of bitterness…
#     <a class="read-more-beerlist track-click" data-bid="1515633" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1515633" style="display: none;">
#     We dry hopped this kettle-soured IPA with Citra, Simcoe and Palisade for a juicy mango-grapefruit flavor and aroma. Sourness takes the place of bitterness in balancing out the sweetness of the malts.
#     <a class="read-less-beerlist track-click" data-bid="1515633" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7.6% ABV
#    </p>
#    <p class="ibu">
#     50 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.81)
#     </span>
#    </p>
#    <p class="raters">
#     2,359 Ratings
#    </p>
#    <p class="date">
#     Added 04/17/16
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1515633" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="462190">
#   <a class="label" href="/b/seventh-son-brewing-company-golden-ratio/462190">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-golden-ratio/462190">
#      Golden Ratio
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-462190">
#     Brewed with local honey. Galaxy, Nelson Sauvin, Moteuka hops. Tasting notes: toasty malts, tropical fruit hops.
#    </p>
#    <p class="desc desc-full-462190" style="display: none;">
#     Brewed with local honey. Galaxy, Nelson Sauvin, Moteuka hops. Tasting notes: toasty malts, tropical fruit hops.
#     <a class="read-less-beerlist track-click" data-bid="462190" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7% ABV
#    </p>
#    <p class="ibu">
#     68 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.75)
#     </span>
#    </p>
#    <p class="raters">
#     1,780 Ratings
#    </p>
#    <p class="date">
#     Added 09/26/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="462190" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="2201055">
#   <a class="label" href="/b/seventh-son-brewing-company-gleen/2201055">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-gleen/2201055">
#      Gleen
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-2201055">
#     Northeast IPA methods and four dry hop additions meet Midwest sensibilities for a burst of pungent hoppy sunshine in this “no coast” IPA from the banks…
#     <a class="read-more-beerlist track-click" data-bid="2201055" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-2201055" style="display: none;">
#     Northeast IPA methods and four dry hop additions meet Midwest sensibilities for a burst of pungent hoppy sunshine in this “no coast” IPA from the banks of the Olentangy.
#     <a class="read-less-beerlist track-click" data-bid="2201055" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7.9% ABV
#    </p>
#    <p class="ibu">
#     55 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (3.91)
#     </span>
#    </p>
#    <p class="raters">
#     1,632 Ratings
#    </p>
#    <p class="date">
#     Added 07/19/17
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="2201055" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="380322">
#   <a class="label" href="/b/seventh-son-brewing-company-lost-sparrow/380322">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-lost-sparrow/380322">
#      Lost Sparrow
#     </a>
#    </p>
#    <p class="style">
#     IPA - Black / Cascadian Dark Ale
#    </p>
#    <p class="desc desc-half-380322">
#     Midnight dark, bracingly bitter yet smooth black IPA with dark malt character balanced by notes of lemon and orange rind from extensive dry hopping with…
#     <a class="read-more-beerlist track-click" data-bid="380322" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-380322" style="display: none;">
#     Midnight dark, bracingly bitter yet smooth black IPA with dark malt character balanced by notes of lemon and orange rind from extensive dry hopping with Sorachi Ace.
#     <a class="read-less-beerlist track-click" data-bid="380322" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     6.7% ABV
#    </p>
#    <p class="ibu">
#     75 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.66)
#     </span>
#    </p>
#    <p class="raters">
#     1,519 Ratings
#    </p>
#    <p class="date">
#     Added 06/07/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="380322" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1868972">
#   <a class="label" href="/b/seventh-son-brewing-company-fox-in-the-stout/1868972">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-fox-in-the-stout/1868972">
#      Fox In the Stout
#     </a>
#    </p>
#    <p class="style">
#     Stout - American Imperial / Double
#    </p>
#    <p class="desc desc-half-1868972">
#     Fox in the Stout Imperial Salted Chocolate Stout: cocoa nibs and fresh vanilla beans along with flaked oats for body make this a big rich dessert stout…
#     <a class="read-more-beerlist track-click" data-bid="1868972" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1868972" style="display: none;">
#     Fox in the Stout Imperial Salted Chocolate Stout: cocoa nibs and fresh vanilla beans along with flaked oats for body make this a big rich dessert stout worthy of its Fox in the Snow brownie inspiration.
#     <a class="read-less-beerlist track-click" data-bid="1868972" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     9.7% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r425">
#     </span>
#     <span class="num">
#      (4.22)
#     </span>
#    </p>
#    <p class="raters">
#     1,501 Ratings
#    </p>
#    <p class="date">
#     Added 12/18/16
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1868972" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="471148">
#   <a class="label" href="/b/seventh-son-brewing-company-wilderman/471148">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-471148_140c5_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-wilderman/471148">
#      Wilderman
#     </a>
#    </p>
#    <p class="style">
#     Bière de Garde
#    </p>
#    <p class="desc desc-half-471148">
#     Inspired by the European pagan Fall tradition of Wilder Mann costumes, our Wildermann is a biere de garde with a bit more hop than French versions and…
#     <a class="read-more-beerlist track-click" data-bid="471148" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-471148" style="display: none;">
#     Inspired by the European pagan Fall tradition of Wilder Mann costumes, our Wildermann is a biere de garde with a bit more hop than French versions and clean farmhouse yeast spice. We lagered for a month which mellows the character of the beer and lets the malt shine.
#     <a class="read-less-beerlist track-click" data-bid="471148" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7.6% ABV
#    </p>
#    <p class="ibu">
#     22 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.68)
#     </span>
#    </p>
#    <p class="raters">
#     1,443 Ratings
#    </p>
#    <p class="date">
#     Added 10/06/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="471148" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="581623">
#   <a class="label" href="/b/seventh-son-brewing-company-mr-owl/581623">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-581623_72b32_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-mr-owl/581623">
#      Mr. Owl
#     </a>
#    </p>
#    <p class="style">
#     Brown Ale - Imperial / Double
#    </p>
#    <p class="desc desc-half-581623">
#     Citra, northern brewer, horizon hops. Housemade Candi Syrup. Tasting notes:rich milk chocolate, tropical fruit, orange zest. bottle release fall, named…
#     <a class="read-more-beerlist track-click" data-bid="581623" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-581623" style="display: none;">
#     Citra, northern brewer, horizon hops. Housemade Candi Syrup. Tasting notes:rich milk chocolate, tropical fruit, orange zest.
#     <br/>
#     bottle release fall, named after the tootsie roll commercial. Have fun and enjoy Mr. Owl with anything from candy-coated lollipops too spicy mole sauce, or even a foie gras torchon.
#     <a class="read-less-beerlist track-click" data-bid="581623" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     8.5% ABV
#    </p>
#    <p class="ibu">
#     73 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.79)
#     </span>
#    </p>
#    <p class="raters">
#     1,445 Ratings
#    </p>
#    <p class="date">
#     Added 02/07/14
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="581623" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="534959">
#   <a class="label" href="/b/seventh-son-brewing-company-ladies-and-gentlemen/534959">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-ladies-and-gentlemen/534959">
#      Ladies And Gentlemen
#     </a>
#    </p>
#    <p class="style">
#     Barleywine - American
#    </p>
#    <p class="desc desc-half-534959">
#     Fine carbonation carries Aromas of peach cake, clementines and flowers, balanced by a firm, Happy bitterness and hints of vanilla icing in the finish.…
#     <a class="read-more-beerlist track-click" data-bid="534959" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-534959" style="display: none;">
#     Fine carbonation carries Aromas of peach cake, clementines and flowers, balanced by a firm, Happy bitterness and hints of vanilla icing in the finish.
#     <a class="read-less-beerlist track-click" data-bid="534959" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     11% ABV
#    </p>
#    <p class="ibu">
#     51 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.82)
#     </span>
#    </p>
#    <p class="raters">
#     1,358 Ratings
#    </p>
#    <p class="date">
#     Added 12/18/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="534959" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1390772">
#   <a class="label" href="/b/seventh-son-brewing-company-brother-jon/1390772">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-brother-jon/1390772">
#      Brother Jon
#     </a>
#    </p>
#    <p class="style">
#     Blonde Ale - Belgian Blonde / Golden
#    </p>
#    <p class="desc desc-half-1390772">
#     Heull Melon, Palisade Hops. A blend of two Belgian abbey style yeasts. Tasting Notes: Faint fruit and spice, crackery malt. Mild beer traditionaly brewed…
#     <a class="read-more-beerlist track-click" data-bid="1390772" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1390772" style="display: none;">
#     Heull Melon, Palisade Hops.
#     <br/>
#     A blend of two Belgian abbey style yeasts. Tasting Notes:
#     <br/>
#     Faint fruit and spice, crackery malt. Mild beer traditionaly brewed by Belgian monks, named after a local celeb and wedding officant Jon Putnam.
#     <a class="read-less-beerlist track-click" data-bid="1390772" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     6.3% ABV
#    </p>
#    <p class="ibu">
#     30 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.63)
#     </span>
#    </p>
#    <p class="raters">
#     1,347 Ratings
#    </p>
#    <p class="date">
#     Added 01/16/16
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1390772" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1057580">
#   <a class="label" href="/b/seventh-son-brewing-company-chester-copperpot/1057580">
#    <img src="https://untappd.akamaized.net/site/beer_logos/beer-1057580_bb6dd_sm.jpeg"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-chester-copperpot/1057580">
#      Chester Copperpot
#     </a>
#    </p>
#    <p class="style">
#     Smoked Beer
#    </p>
#    <p class="desc desc-half-1057580">
#     Old-school German-style Hallertauer Hersbrucker, Willamette hops. Beech and Cherrywood smoked malts. Tasting notes: Sweet smokiness, clean bodied, herbal…
#     <a class="read-more-beerlist track-click" data-bid="1057580" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1057580" style="display: none;">
#     Old-school German-style Hallertauer Hersbrucker, Willamette hops. Beech and Cherrywood smoked malts. Tasting notes: Sweet smokiness, clean bodied, herbal lingering bitterness. Goonies never say die!!
#     <a class="read-less-beerlist track-click" data-bid="1057580" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7.9% ABV
#    </p>
#    <p class="ibu">
#     6 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.7)
#     </span>
#    </p>
#    <p class="raters">
#     1,323 Ratings
#    </p>
#    <p class="date">
#     Added 04/23/15
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1057580" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="557738">
#   <a class="label" href="/b/seventh-son-brewing-company-willowolf/557738">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-willowolf/557738">
#      Willowolf
#     </a>
#    </p>
#    <p class="style">
#     IPA - Imperial / Double
#    </p>
#    <p class="desc desc-half-557738">
#     Amarillo, Centennial, Horizon hops. Tasting notes:bitter pine and citrus, sweet finish. named for an archaic term for the hops plant, because the vines…
#     <a class="read-more-beerlist track-click" data-bid="557738" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-557738" style="display: none;">
#     Amarillo, Centennial, Horizon hops. Tasting notes:bitter pine and citrus, sweet finish. named for an archaic term for the hops plant, because the vines can choke willow trees
#     <a class="read-less-beerlist track-click" data-bid="557738" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     9.3% ABV
#    </p>
#    <p class="ibu">
#     120 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (3.92)
#     </span>
#    </p>
#    <p class="raters">
#     1,159 Ratings
#    </p>
#    <p class="date">
#     Added 01/11/14
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="557738" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1309047">
#   <a class="label" href="/b/seventh-son-brewing-company-rime/1309047">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-rime/1309047">
#      Rime
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-1309047">
#     Lightly spiced Winter IPA uses fresh ginger, coriander, and caramelized orange peels
#    </p>
#    <p class="desc desc-full-1309047" style="display: none;">
#     Lightly spiced Winter IPA uses fresh ginger, coriander, and caramelized orange peels
#     <a class="read-less-beerlist track-click" data-bid="1309047" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     6.5% ABV
#    </p>
#    <p class="ibu">
#     53 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.78)
#     </span>
#    </p>
#    <p class="raters">
#     1,166 Ratings
#    </p>
#    <p class="date">
#     Added 11/11/15
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1309047" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="496043">
#   <a class="label" href="/b/seventh-son-brewing-company-black-sheep/496043">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-black-sheep/496043">
#      Black Sheep
#     </a>
#    </p>
#    <p class="style">
#     Stout - Other
#    </p>
#    <p class="desc desc-half-496043">
#     This dry-hopped American stout has a full body with notes of fresh roasted coffee, cocoa and cherrywood smoke.
#    </p>
#    <p class="desc desc-full-496043" style="display: none;">
#     This dry-hopped American stout has a full body with notes of fresh roasted coffee, cocoa and cherrywood smoke.
#     <a class="read-less-beerlist track-click" data-bid="496043" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7% ABV
#    </p>
#    <p class="ibu">
#     30 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.64)
#     </span>
#    </p>
#    <p class="raters">
#     1,096 Ratings
#    </p>
#    <p class="date">
#     Added 11/04/13
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="496043" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1534210">
#   <a class="label" href="/b/seventh-son-brewing-company-hadron-s-collision-table-beer/1534210">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-hadron-s-collision-table-beer/1534210">
#      Hadron's Collision Table Beer
#     </a>
#    </p>
#    <p class="style">
#     Saison / Farmhouse Ale
#    </p>
#    <p class="desc desc-half-1534210">
#     Light cantaloupe aroma and flavors arrive courtesy of the singular Huell Melon hops
#    </p>
#    <p class="desc desc-full-1534210" style="display: none;">
#     Light cantaloupe aroma and flavors arrive courtesy of the singular Huell Melon hops
#     <a class="read-less-beerlist track-click" data-bid="1534210" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     3.4% ABV
#    </p>
#    <p class="ibu">
#     20 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r325">
#     </span>
#     <span class="num">
#      (3.32)
#     </span>
#    </p>
#    <p class="raters">
#     1,074 Ratings
#    </p>
#    <p class="date">
#     Added 04/30/16
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1534210" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1286407">
#   <a class="label" href="/b/seventh-son-brewing-company-laniakea/1286407">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-laniakea/1286407">
#      Laniakea
#     </a>
#    </p>
#    <p class="style">
#     IPA - Imperial / Double
#    </p>
#    <p class="desc desc-half-1286407">
#     Laniakea (La-ni-akea)Loads of Galaxy and Mosaic hops dominate this hugely aromatic double named for the cosmic super cluster that is home to our own Milky…
#     <a class="read-more-beerlist track-click" data-bid="1286407" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1286407" style="display: none;">
#     Laniakea (La-ni-akea)Loads of Galaxy and Mosaic hops dominate this hugely aromatic double named for the cosmic super cluster that is home to our own Milky Way.
#     <a class="read-less-beerlist track-click" data-bid="1286407" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     9.5% ABV
#    </p>
#    <p class="ibu">
#     100 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (3.98)
#     </span>
#    </p>
#    <p class="raters">
#     1,021 Ratings
#    </p>
#    <p class="date">
#     Added 10/24/15
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1286407" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1256707">
#   <a class="label" href="/b/seventh-son-brewing-company-sun-mouth/1256707">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-sun-mouth/1256707">
#      Sun Mouth
#     </a>
#    </p>
#    <p class="style">
#     Saison / Farmhouse Ale
#    </p>
#    <p class="desc desc-half-1256707">
#     This off-dry strong saison has a melange of fruit and spice flavors. Sorachi Ace and Citra hops bring dill and candied lemon while our blend of farmhouse…
#     <a class="read-more-beerlist track-click" data-bid="1256707" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1256707" style="display: none;">
#     This off-dry strong saison has a melange of fruit and spice flavors. Sorachi Ace and Citra hops bring dill and candied lemon while our blend of farmhouse yeast layer in white pepper spice. Pilsner and wheat malts lend a bready finish. Put the sun in your mouth
#     <a class="read-less-beerlist track-click" data-bid="1256707" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     8.3% ABV
#    </p>
#    <p class="ibu">
#     30 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.66)
#     </span>
#    </p>
#    <p class="raters">
#     986 Ratings
#    </p>
#    <p class="date">
#     Added 10/01/15
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1256707" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1441216">
#   <a class="label" href="/b/seventh-son-brewing-company-abaddon/1441216">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-abaddon/1441216">
#      Abaddon
#     </a>
#    </p>
#    <p class="style">
#     Belgian Quad
#    </p>
#    <p class="desc desc-half-1441216">
#     Mosaic, Saaz hops. Dark housemade candi syrups, abbey yeast blend, spices. Tasting notes: Dried fruit, bitter orange, white pepper, port wine sweetness.…
#     <a class="read-more-beerlist track-click" data-bid="1441216" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1441216" style="display: none;">
#     Mosaic, Saaz hops.
#     <br/>
#     Dark housemade candi syrups, abbey yeast blend, spices.
#     <br/>
#     Tasting notes:
#     <br/>
#     Dried fruit, bitter orange, white pepper, port wine sweetness.
#     <br/>
#     Named after a destroying angel
#     <a class="read-less-beerlist track-click" data-bid="1441216" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     10% ABV
#    </p>
#    <p class="ibu">
#     30 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.86)
#     </span>
#    </p>
#    <p class="raters">
#     971 Ratings
#    </p>
#    <p class="date">
#     Added 02/25/16
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-bid="1441216" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1249048">
#   <a class="label" href="/b/seventh-son-brewing-company-the-wild-hunt/1249048">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-the-wild-hunt/1249048">
#      The Wild Hunt
#     </a>
#    </p>
#    <p class="style">
#     Barleywine - English
#    </p>
#    <p class="desc desc-half-1249048">
#     Inspired by the myths, legends and magic of the English countryside, this barleywine marks the transition from the exuberance of Summer to the hush of…
#     <a class="read-more-beerlist track-click" data-bid="1249048" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-1249048" style="display: none;">
#     Inspired by the myths, legends and magic of the English countryside, this barleywine marks the transition from the exuberance of Summer to the hush of Autumn. Premium English malts lend a rich body, juicy cherry notes and a deep caramel complexity. Assertively hopped when fresh, this layered ale will continue to evolve in the bottle for many years.
#     <a class="read-less-beerlist track-click" data-bid="1249048" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     9.8% ABV
#    </p>
#    <p class="ibu">
#     55 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.78)
#     </span>
#    </p>
#    <p class="raters">
#     954 Ratings
#    </p>
#    <p class="date">
#     Added 09/25/15
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="1249048" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="2125648">
#   <a class="label" href="/b/seventh-son-brewing-company-qahwah-arab-imperial-coffee-stout/2125648">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-qahwah-arab-imperial-coffee-stout/2125648">
#      Qahwah Arab Imperial Coffee Stout
#     </a>
#    </p>
#    <p class="style">
#     Stout - American
#    </p>
#    <p class="desc desc-half-2125648">
#     Arab Coffee Stout. A medium bodied Imperial Stout infused with Mission Coffee beans, cardamom, clove, cinnamon and ginger.
#    </p>
#    <p class="desc desc-full-2125648" style="display: none;">
#     Arab Coffee Stout. A medium bodied Imperial Stout infused with Mission Coffee beans, cardamom, clove, cinnamon and ginger.
#     <a class="read-less-beerlist track-click" data-bid="2125648" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     9% ABV
#    </p>
#    <p class="ibu">
#     40 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r400">
#     </span>
#     <span class="num">
#      (4.12)
#     </span>
#    </p>
#    <p class="raters">
#     861 Ratings
#    </p>
#    <p class="date">
#     Added 06/03/17
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="2125648" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="2335634">
#   <a class="label" href="/b/seventh-son-brewing-company-lemongrass-wit-sketch/2335634">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-lemongrass-wit-sketch/2335634">
#      Lemongrass Wit
#     </a>
#    </p>
#    <p class="style">
#     Witbier
#    </p>
#    <p class="desc desc-half-2335634">
#     A new-world spin on the classic Belgian Wit. Lemongrass, lime leaves and Lemondrop hops combine with fresh ground coriander to give this quenching wheat…
#     <a class="read-more-beerlist track-click" data-bid="2335634" data-href=":readmorebeer" data-track="brewerylist" href="#">
#      Read More
#     </a>
#    </p>
#    <p class="desc desc-full-2335634" style="display: none;">
#     A new-world spin on the classic Belgian Wit. Lemongrass, lime leaves and Lemondrop hops combine with fresh ground coriander to give this quenching wheat ale a citrusy zip.
#     <a class="read-less-beerlist track-click" data-bid="2335634" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     4.9% ABV
#    </p>
#    <p class="ibu">
#     10 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r375">
#     </span>
#     <span class="num">
#      (3.65)
#     </span>
#    </p>
#    <p class="raters">
#     867 Ratings
#    </p>
#    <p class="date">
#     Added 10/12/17
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="2335634" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="1431911">
#   <a class="label" href="/b/seventh-son-brewing-company-baphomet/1431911">
# ...
#   <a class="label" href="/b/seventh-son-brewing-company-seveth-son-scientist-5ai/3059258">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-seveth-son-scientist-5ai/3059258">
#      Seveth Son Scientist #5AI
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-3059258">
#     American IPA
#    </p>
#    <p class="desc desc-full-3059258" style="display: none;">
#     American IPA
#     <a class="read-less-beerlist track-click" data-bid="3059258" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7% ABV
#    </p>
#    <p class="ibu">
#     75 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     5 Ratings
#    </p>
#    <p class="date">
#     Added 01/30/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3059258" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3195710">
#   <a class="label" href="/b/seventh-son-brewing-company-sike/3195710">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-sike/3195710">
#      Sike
#     </a>
#    </p>
#    <p class="style">
#     Sour - Fruited
#    </p>
#    <p class="desc desc-half-3195710">
#    </p>
#    <p class="desc desc-full-3195710" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3195710" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     N/A ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     6 Ratings
#    </p>
#    <p class="date">
#     Added 04/25/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3195710" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3072514">
#   <a class="label" href="/b/seventh-son-brewing-company-seventh-son-saddle-lamp/3072514">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-seventh-son-saddle-lamp/3072514">
#      Seventh Son Saddle Lamp
#     </a>
#    </p>
#    <p class="style">
#     Sour - Ale
#    </p>
#    <p class="desc desc-half-3072514">
#    </p>
#    <p class="desc desc-full-3072514" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3072514" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     6.8% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     5 Ratings
#    </p>
#    <p class="date">
#     Added 02/08/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3072514" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3142240">
#   <a class="label" href="/b/seventh-son-brewing-company-seventh-son-stone-fort-coffee-and-vanilla-cask/3142240">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-seventh-son-stone-fort-coffee-and-vanilla-cask/3142240">
#      Seventh Son Stone Fort Coffee And Vanilla Cask
#     </a>
#    </p>
#    <p class="style">
#     Brown Ale - American
#    </p>
#    <p class="desc desc-half-3142240">
#    </p>
#    <p class="desc desc-full-3142240" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3142240" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     5.3% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     5 Ratings
#    </p>
#    <p class="date">
#     Added 03/23/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3142240" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3187805">
#   <a class="label" href="/b/seventh-son-brewing-company-proliferous-2019/3187805">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-proliferous-2019/3187805">
#      Proliferous 2019
#     </a>
#    </p>
#    <p class="style">
#     IPA - Imperial / Double
#    </p>
#    <p class="desc desc-half-3187805">
#    </p>
#    <p class="desc desc-full-3187805" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3187805" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     8.3% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     4 Ratings
#    </p>
#    <p class="date">
#     Added 04/20/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3187805" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3066342">
#   <a class="label" href="/b/seventh-son-brewing-company-scientist-5aj/3066342">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-scientist-5aj/3066342">
#      Scientist 5AJ
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-3066342">
#    </p>
#    <p class="desc desc-full-3066342" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3066342" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     4 Ratings
#    </p>
#    <p class="date">
#     Added 02/03/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3066342" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3143625">
#   <a class="label" href="/b/seventh-son-brewing-company-barrel-aged-oubliette-2019/3143625">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-barrel-aged-oubliette-2019/3143625">
#      Barrel Aged Oubliette 2019
#     </a>
#    </p>
#    <p class="style">
#     Stout - American Imperial / Double
#    </p>
#    <p class="desc desc-half-3143625">
#     Blended from ages of Oubliette that spent time in two rum barrels, two bourbon barrels and an apple brandy barrel
#    </p>
#    <p class="desc desc-full-3143625" style="display: none;">
#     Blended from ages of Oubliette that spent time in two rum barrels, two bourbon barrels and an apple brandy barrel
#     <a class="read-less-beerlist track-click" data-bid="3143625" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     13% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     4 Ratings
#    </p>
#    <p class="date">
#     Added 03/24/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3143625" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3182114">
#   <a class="label" href="/b/seventh-son-brewing-company-low-hanging-fruit/3182114">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-low-hanging-fruit/3182114">
#      Low Hanging Fruit
#     </a>
#    </p>
#    <p class="style">
#     Sour - Farmhouse IPA
#    </p>
#    <p class="desc desc-half-3182114">
#    </p>
#    <p class="desc desc-full-3182114" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3182114" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7.2% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     4 Ratings
#    </p>
#    <p class="date">
#     Added 04/17/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3182114" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3148710">
#   <a class="label" href="/b/seventh-son-brewing-company-the-scientist-4al/3148710">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-the-scientist-4al/3148710">
#      The Scientist #4AL
#     </a>
#    </p>
#    <p class="style">
#     IPA - American
#    </p>
#    <p class="desc desc-half-3148710">
#    </p>
#    <p class="desc desc-full-3148710" style="display: none;">
#     <a class="read-less-beerlist track-click" data-bid="3148710" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     7% ABV
#    </p>
#    <p class="ibu">
#     70 IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     1 Rating
#    </p>
#    <p class="date">
#     Added 03/28/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3148710" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
#  <div class="beer-item" data-bid="3200294">
#   <a class="label" href="/b/seventh-son-brewing-company-dang-w-pineapple-mango-and-habanero/3200294">
#    <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#   </a>
#   <div class="beer-details">
#    <p class="name">
#     <a href="/b/seventh-son-brewing-company-dang-w-pineapple-mango-and-habanero/3200294">
#      Dang! W/ Pineapple, Mango And Habanero
#     </a>
#    </p>
#    <p class="style">
#     IPA - Imperial / Double
#    </p>
#    <p class="desc desc-half-3200294">
#     Infused
#    </p>
#    <p class="desc desc-full-3200294" style="display: none;">
#     Infused
#     <a class="read-less-beerlist track-click" data-bid="3200294" data-href=":readlessbeer" data-track="brewerylist" href="#">
#      Read Less
#     </a>
#    </p>
#   </div>
#   <div class="details">
#    <p class="abv">
#     9.7% ABV
#    </p>
#    <p class="ibu">
#     N/A IBU
#    </p>
#    <p class="rating">
#     <span class="rating small r000">
#     </span>
#     <span class="num">
#      (
#      <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#       N/A
#      </a>
#      )
#     </span>
#    </p>
#    <p class="raters">
#     1 Rating
#    </p>
#    <p class="date">
#     Added 04/27/19
#    </p>
#   </div>
#   <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3200294" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#    Add
#   </a>
#  </div>
# </div>

# %% [markdown]
# As we can see from the `prettify()` output this html code is more complicated than our toy example from above, but `BeautifulSoup` is able to handle it all the same. Let's write some code to go through the html and grab the beer names and then store those names in a list.
#
# To do that let's learn a little more about BeautifulSoup's functionality. Looking at the prettify output we see that each beer is contained in a "beer-item". We can use that class information to our advantage.

# %%
cooler = soup.find_all('div',{'class':"beer-item"})

# %%
beer0 = cooler[0]

# %%
beer0
# Out:
# <div class="beer-item" data-bid="382779">
# <a class="label" href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-382779_814af_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-humulus-nimbus/382779">Humulus Nimbus </a></p>
# <p class="style">Pale Ale - American</p>
# <p class="desc desc-half-382779">A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart… <a class="read-more-beerlist track-click" data-bid="382779" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-382779" style="display: none;">A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart blueberry and fragrant pine to a pleasingly bitter dandelion finish. We wanted the hops to be the star in this seasonal offering taking its name from both the hop plant, Humulus Lupulus, and its light color and cloud-like feel, nimbus. <br/>
# *Pairs well with a wide range of foods from roast chicken to burgers to fish and chips, appropriate cheeses could range from a mild blue such as Gorgonzola to a traditional cheddar or Derby with Sage. <a class="read-less-beerlist track-click" data-bid="382779" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6% ABV </p><p class="ibu">
# 53 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.81)</span> </p><p class="raters">
# 10,319 Ratings </p><p class="date">
# Added 06/10/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="382779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>

# %%
# Now use what we just learned to extract the name from beer 0
# The name is contained in a p element with class "name"
print(beer0.find("p",{'class':"name"}))
# Out:
# <p class="name"><a href="/b/seventh-son-brewing-company-humulus-nimbus/382779">Humulus Nimbus </a></p>

# %%
# Now make a list of all the beer names
beers = [beer.find("p",{'class':"name"}).text for beer in cooler]

# %%
beers

# %% [markdown]
# #### Practice
#
# You've been hired by a competitor to SeventhSon. They want a dataframe of all of SeventhSon's beers that includes their name, beer type, abv, and ibu. Use BeautifulSoup to give them this.

# %%
# Your work here
beers_name = [beer.find("p",{'class':"name"}).text for beer in cooler]
beers_type = [beer.find("p",{'class':"style"}).text for beer in cooler]
beers_abv = [beer.find("p",{'class':"abv"}).text for beer in cooler]
beers_ibu = [beer.find("p",{'class':"ibu"}).text for beer in cooler]

beer_df = pd.DataFrame({'name':beers_name,'type':beers_type, 'abv':beers_abv, 'ibu':beers_ibu})

beer_df.head()
# Out:
#                               name                     type           abv  \
# 0                  Humulus Nimbus       Pale Ale - American     \n6% ABV
# 1                      Proliferous  IPA - Imperial / Double   \n8.3% ABV
# 2                    The Scientist           IPA - American     \n7% ABV
# 3  Seventh Son American Strong Ale    Strong Ale - American   \n7.7% ABV
# 4             Stone Fort Oat Brown      Brown Ale - English  \n5.25% ABV
#
#          ibu
# 0  \n53 IBU
# 1  \n85 IBU
# 2  \n75 IBU
# 3  \n40 IBU
# 4  \n21 IBU

# %%
## lets do some processing to remove charecters from abv and ibu
def removeABV(string):
    string = string.lstrip('\n')
    string = string.rstrip('% ABV')
    return string

def removeIBU(string):
    string = string.lstrip('\n')
    string = string.rstrip(' IBU')
    return string
    

beer_df['abv'] = beer_df['abv'].apply(lambda x: removeABV(x))
beer_df['ibu'] = beer_df['ibu'].apply(lambda x: removeIBU(x))
beer_df.head()
# Out:
#                               name                     type   abv ibu
# 0                  Humulus Nimbus       Pale Ale - American     6  53
# 1                      Proliferous  IPA - Imperial / Double   8.3  85
# 2                    The Scientist           IPA - American     7  75
# 3  Seventh Son American Strong Ale    Strong Ale - American   7.7  40
# 4             Stone Fort Oat Brown      Brown Ale - English  5.25  21

# %%
# How many of each type of beer?


beer_df.groupby('type').size()
# Out:
# type
# Barleywine - American                    2
# Barleywine - English                     1
# Belgian Dubbel                           1
# Belgian Quad                             1
# Belgian Tripel                           1
# Bière de Garde                           2
# Blonde Ale                               1
# Blonde Ale - Belgian Blonde / Golden     2
# Brown Ale - American                     1
# Brown Ale - English                      1
# Brown Ale - Imperial / Double            1
# Dark Ale                                 1
# English Mild Ale                         1
# Fruit Beer                               1
# Golden Ale                               1
# IPA - American                          17
# IPA - Belgian                            1
# IPA - Black / Cascadian Dark Ale         3
# IPA - Brut                               4
# IPA - Imperial / Double                  9
# IPA - New England                        6
# IPA - Session / India Session Ale        1
# IPA - White                              1
# Lager - Euro                             2
# Lager - IPL (India Pale Lager)           2
# Pale Ale - American                      7
# Pale Ale - Belgian                       1
# Pale Ale - International                 1
# Pale Ale - New England                   3
# Porter - Baltic                          1
# Saison / Farmhouse Ale                  11
# Smoked Beer                              4
# Sour - Ale                               1
# Sour - Farmhouse IPA                     3
# Sour - Fruited                           1
# Stout - American                         2
# Stout - American Imperial / Double       4
# Stout - Coffee                           1
# Stout - Foreign / Export                 1
# Stout - Imperial / Double                3
# Stout - Milk / Sweet                     1
# Stout - Other                            1
# Strong Ale - American                    1
# Strong Ale - English                     1
# Witbier                                  1
# dtype: int64

# %% [markdown]
# Great! We're finally getting familiar enough with BeautifulSoup to move on to an actual website.
#
# ### Surfing the web
#
# Here's our hypothetical project. Your hired by someone that wants to start a FiveThirtyEight like website, but hates writing. Their goal is to create a natural language bot that uses an NLP algorithm to generate new 538 like articles using previous 538 articles. They're too busy working on the algorithm so they've outsourced the job of scraping the article content to us.
#
# Their desired output is a compilation of 538's articles. The data they need is each article's title, author, and text.
#
# Let's go through how to get the title, author, and text for one specific article.

# %%
# This method allows us to get the html code from 538
from urllib.request import urlopen

# %%
# Grab the html from the article
html = urlopen("https://fivethirtyeight.com/features/giannis-antetokounmpo-is-creating-more-than-ever/")

# %%
# Turn it into soup
soup = BeautifulSoup(html,"html.parser")

# %%
print(soup.prettify())

# %% [markdown]
# We can see that going through the code might be annoying. Let's learn about the web developer tools of your web browser.
#
#
# #### Your Turn
#
# Now that we've reviewed how we can use the developer tools you try to write the code that will grab the desired info.

# %%
# Find the author here
author_name = soup.find('div',{'class':"single-header-metadata-wrap"}).find("p",{'class':"single-metadata single-byline vcard"}).text
author_name

soup.find('div',{'class':"single-header-metadata-wrap"})

# %%
# Find the title here

article_title = soup.find('div',{'class':"single-header"}).find("h1",{'class':"article-title article-title-single entry-title"}).text

article_title.strip('\n\t')

# %%
# Find the text of the article here

article_content = soup.find('div',{'class':"entry-content single-post-content"}).text
article_content

# %% [markdown]
# Now you've got a good introduction to web sraping with `BeautifulSoup`. If you want to dive deeper check out the documentation here, <a href = "https://www.crummy.com/software/BeautifulSoup/bs4/doc/">https://www.crummy.com/software/BeautifulSoup/bs4/doc/</a>, or you can try searching the web for what you'd like to do.
